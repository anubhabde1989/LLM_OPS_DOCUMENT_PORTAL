# %%
print("All Okay!")
# Out:
# All Okay!

# %%
import sys 
import traceback

# %%
from logger.custom_logger import CustomLogger

# %%
logger = CustomLogger().get_logger('exception_experiment')

# %%
class DocumentPortalException(Exception):
    """Custom Exception for Document Portal"""
    def __init__(self, error_message:str, error_details:sys):
        _,_,exc_tb=error_details.exc_info()
        self.file_name=exc_tb.tb_frame.f_code.co_filename
        self.line_no=exc_tb.tb_lineno
        self.error_message=str(error_message)
        self.traceback_str = ''.join(traceback.format_exception(*error_details.exc_info()))

    def __str__(self):
        return f"Error in file: {self.file_name} at line: {self.line_no} Message: {self.error_message} {self.traceback_str}"

if __name__ == "__main__":
    try:
        #Simulate an error
        a=1/0
        print(a)
    except Exception as e:
        app_exc = DocumentPortalException(e, sys)
        logger.error(app_exc)
        raise app_exc
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[11], line 16
#      14 try:
#      15     #Simulate an error
# ---> 16     a=1/0
#      17     print(a)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# DocumentPortalException                   Traceback (most recent call last)
# Cell In[11], line 21
#      19 app_exc = DocumentPortalException(e, sys)
#      20 logger.error(app_exc)
# ---> 21 raise app_exc
#
# DocumentPortalException: Error in file: C:\Users\anubh\AppData\Local\Temp\ipykernel_14660\1004704897.py at line: 16 Message: division by zero Traceback (most recent call last):
#   File "C:\Users\anubh\AppData\Local\Temp\ipykernel_14660\1004704897.py", line 16, in <module>
#     a=1/0
# ZeroDivisionError: division by zero
