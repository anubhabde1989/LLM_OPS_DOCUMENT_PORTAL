# %%
print("All Okay!")
# Out:
# All Okay!

# %%
import logging
import os 
from datetime import datetime

# %%
os.path.join(os.getcwd(), "logs")
# Out:
# 'd:\\LLM Ops Project\\document_portal\\notebook\\logs'

# %%
logs_dir=os.path.join(os.getcwd(), "logs")
os.makedirs(logs_dir, exist_ok=True)

# %%
LOG_FILE = f"{datetime.now().strftime('%m-%d-%Y-%H-%M-%S')}.log"

# %%
LOG_FILE
# Out:
# '06-01-2026-23-24-43.log'

# %%
LOG_FILE_PATH = os.path.join(logs_dir, LOG_FILE)

# %%
LOG_FILE_PATH
# Out:
# 'd:\\LLM Ops Project\\document_portal\\notebook\\logs\\06-01-2026-23-24-43.log'

# %%
logging.basicConfig(filename=LOG_FILE_PATH, 
                    format="[%(asctime)s] %(levelname)s %(name)s (line:%(lineno)d) - %(message)s", 
                    level=logging.INFO,
                    )

# %%
logger=logging.getLogger("DocumentPortal")

# %%
logger.info("This is an info message")

# %%
import structlog

# %%
log=structlog.get_logger()

# %%
log.info("This is an info message from structlog", user_id=123, filename="report.pdf")
# Out:
# 2026-06-01 23:24:46 [info     ] This is an info message from structlog filename=report.pdf user_id=123
